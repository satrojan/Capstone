# %%
import pandas as pd

# %%
df = pd.DataFrame({'sub_name':['dankmemes',#33
                                'teenagers',#               33
                                'FortNiteBR',#              30
                                'Kanye',#                   27
                                'hmmm',# 27,
                                'DiepioPartyLinks',#        10
                                'Psychonaut',#               8
                                'stalker',#                  6
                                'Standup',#                  4
                                'SandersForPresident',#      4
                                'dadjokes',
                                'darkjokes',
                                'WritingPrompts',
                                'oneliners',
                                'AntiJokes',
                                'NBA2kTeamUp',
                                'MaddenUltimateTeam',
                                'Rainbow6',
                                'NBAlive',
                                'FIFA',
                                'askscience',
                                'unpopularopinion',
                                'TooAfraidToAsk',
                                'tipofmytongue',
                                'findareddit',
                                'memes',
                                'gaming',
                                'The_Mueller',
                                'BlackPeopleTwitter',
                                'WTF',
                                'LifeProTips',
                                'ShittyLifeProTips',
                                'CrazyIdeas',
                                'leagueoflegends',
                                'DoesAnybodyElse',
                                'relationships',
                                'Advice',
                                'sex',
                                'SuicideWatch',
                                'AskWomen',
                                'AskEurope',
                                'ukpolitics',
                                'Romania',
                                'travel',
                                'europeanunion',
                                'Drugs',
                                'DotA2',
                                'legaladvice',
                                'AskHistorians',
                                'personalfinance',
                                'aww',
                                'movies',
                                'pics',
                                #'hmmm',
                                'mildlyinteresting',
                                'Music',
                                'listentothis',
                                'Kanye',
                                'hiphop',
                                'Eminem',
                                'bakchodi',
                                'bangalore',
                                'Android',
                                'quotes',
                                'marvelstudios',
                                'nbaleaguesim2019',
                                'Louisville',
                                'borrow',
                                'MMA',
                                'DunkNation3x3',
                                'florida',
                                'Health',
                                'tech', 
                                'television',
                                'healthcare',
                                'fantasyfootball',
                                'Fantasy_Football',
                                'u_Autotradenews',
                                'minnesotavikings',
                                'baseball',
                                'apple',
                                'GDmaze',
                                'shittyaskscience',
                                'newzealand',
                                'smashbros',
                                'Cumtown',
                                'SquaredCircle',
                                'Boxing',
                                'LSAT',
                                'morbidquestions',
                                'EverythingScience',
                                'space',
                                'IRstudies',
                                'dirtykikpals',
                                'BlueMidterm2018',
                                'Juve',
                                'IndianFootball',
                                'FIFA',
                                'LiverpoolFC',
                                'reddevils',
                                'gadgets',
                                'privacy',
                                'de',
                                'web_design',
                                'RandomThoughts',
                                'minnesotavikings',
                                'streetwear',
                                'Fireteams',
                                'OrlandoMagic',
                                'tmobile',
                                'DnD',
                                'answers',
                                'opennms'
                                'CircleofTrust',
                                'youtubehaiku',
                                'youtube',
                                'copypasta',
                                'gifs',
                                'NYYankees',
                                'mlb',
                                'redsox',
                                'dataisbeautiful',
                                'Broadway']})

# %%
df = pd.DataFrame({'sub_name':list(df.sub_name.unique())})

# %%
df_temp = df.copy()

# %%
df_temp
# Out:
#                  sub_name
# 0               dankmemes
# 1               teenagers
# 2              FortNiteBR
# 3                   Kanye
# 4                    hmmm
# 5        DiepioPartyLinks
# 6              Psychonaut
# 7                 stalker
# 8                 Standup
# 9     SandersForPresident
# 10               dadjokes
# 11              darkjokes
# 12         WritingPrompts
# 13              oneliners
# 14              AntiJokes
# 15            NBA2kTeamUp
# 16     MaddenUltimateTeam
# 17               Rainbow6
# 18                NBAlive
# 19                   FIFA
# 20             askscience
# 21       unpopularopinion
# 22         TooAfraidToAsk
# 23          tipofmytongue
# 24            findareddit
# 25                  memes
# 26                 gaming
# 27            The_Mueller
# 28     BlackPeopleTwitter
# 29                    WTF
# ..                    ...
# 88      EverythingScience
# 89                  space
# 90              IRstudies
# ...

# %%
df_temp.to_csv('./workfile.csv',index=False)
